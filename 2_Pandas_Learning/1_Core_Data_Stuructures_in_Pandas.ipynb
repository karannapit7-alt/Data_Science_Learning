# %%
import pandas as pd

# %%
# Series 1D Labeled Array.

# %%
s = pd.Series([85,95,45,96,78,63,45])
print(s)
print(type(s))
print("print zero index",s[0])
# Out:
# 0    85
# 1    95
# 2    45
# 3    96
# 4    78
# 5    63
# 6    45
# dtype: int64
# <class 'pandas.core.series.Series'>
# print zero index 85

# %%
# Series 1d Labeled Array indxing.

S1 = pd.Series([85,95,45,96,78,63,45], index=["Karan","Vishal","Ansh","Arjun","Rahul","Kunal","Tanmay"])
print(S1)
# Out:
# Karan     85
# Vishal    95
# Ansh      45
# Arjun     96
# Rahul     78
# Kunal     63
# Tanmay    45
# dtype: int64

# %%
print(S1["Vishal"])
# Out:
# 95

# %%
print(S1["Karan"])
# Out:
# 85

# %%
# Data Fream.

info = {
    "Name" : ["Karan","Rajesh","Arjun","Vishal"],
    "Roll.No" : [735,712,770,798],
    "Marks" : [98,85,99,45]
}

df = pd.DataFrame(info) 
print(df)
# Out:
#      Name  Roll.No  Marks
# 0   Karan      735     98
# 1  Rajesh      712     85
# 2   Arjun      770     99
# 3  Vishal      798     45

# %%
df
# Out:
#      Name  Roll.No  Marks
# 0   Karan      735     98
# 1  Rajesh      712     85
# 2   Arjun      770     99
# 3  Vishal      798     45

# %%
df.index
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
df.columns
# Out:
# Index(['Name', 'Roll.No', 'Marks'], dtype='object')
